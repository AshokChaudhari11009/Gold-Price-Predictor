# %% [markdown]
# Importing Libraries 📚

# %%
# Importing libraries that will be used in this Notebook.
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Data Collection & Processing

# %%
# Loading the csv data to a Pandas Dataframe
gold_data = pd.read_csv(r"C:\Users\ASHOK\Desktop\Final Project\ML\gold_price_predictor-main\gold_price_predictor-main\gld_price_data.csv")

# %%
gold_data
# Out:
#            Date          SPX         GLD        USO      SLV   EUR/USD
# 0      1/2/2008  1447.160034   84.860001  78.470001  15.1800  1.471692
# 1      1/3/2008  1447.160034   85.570000  78.370003  15.2850  1.474491
# 2      1/4/2008  1411.630005   85.129997  77.309998  15.1670  1.475492
# 3      1/7/2008  1416.180054   84.769997  75.500000  15.0530  1.468299
# 4      1/8/2008  1390.189941   86.779999  76.059998  15.5900  1.557099
# ...         ...          ...         ...        ...      ...       ...
# 2285   5/8/2018  2671.919922  124.589996  14.060000  15.5100  1.186789
# 2286   5/9/2018  2697.790039  124.330002  14.370000  15.5300  1.184722
# 2287  5/10/2018  2723.070068  125.180000  14.410000  15.7400  1.191753
# 2288  5/14/2018  2730.129883  124.489998  14.380000  15.5600  1.193118
# 2289  5/16/2018  2725.780029  122.543800  14.405800  15.4542  1.182033
#
# [2290 rows x 6 columns]

# %%
# first 5 rows of the dataframe
gold_data.head()
# Out:
#        Date          SPX        GLD        USO     SLV   EUR/USD
# 0  1/2/2008  1447.160034  84.860001  78.470001  15.180  1.471692
# 1  1/3/2008  1447.160034  85.570000  78.370003  15.285  1.474491
# 2  1/4/2008  1411.630005  85.129997  77.309998  15.167  1.475492
# 3  1/7/2008  1416.180054  84.769997  75.500000  15.053  1.468299
# 4  1/8/2008  1390.189941  86.779999  76.059998  15.590  1.557099

# %%
# #Using hide_index() from the style function
# gold_data.head().style.hide_index()

# Using hide(axis='index') from the style function
gold_data.head().style.hide(axis='index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_560eb">
#   <thead>
#     <tr>
#       <th id="T_560eb_level0_col0" class="col_heading level0 col0" >Date</th>
#       <th id="T_560eb_level0_col1" class="col_heading level0 col1" >SPX</th>
#       <th id="T_560eb_level0_col2" class="col_heading level0 col2" >GLD</th>
#       <th id="T_560eb_level0_col3" class="col_heading level0 col3" >USO</th>
#       <th id="T_560eb_level0_col4" class="col_heading level0 col4" >SLV</th>
#       <th id="T_560eb_level0_col5" class="col_heading level0 col5" >EUR/USD</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_560eb_row0_col0" class="data row0 col0" >1/2/2008</td>
#       <td id="T_560eb_row0_col1" class="data row0 col1" >1447.160034</td>
#       <td id="T_560eb_row0_col2" class="data row0 col2" >84.860001</td>
#       <td id="T_560eb_row0_col3" class="data row0 col3" >78.470001</td>
#       <td id="T_560eb_row0_col4" class="data row0 col4" >15.180000</td>
#       <td id="T_560eb_row0_col5" class="data row0 col5" >1.471692</td>
#     </tr>
#     <tr>
#       <td id="T_560eb_row1_col0" class="data row1 col0" >1/3/2008</td>
#       <td id="T_560eb_row1_col1" class="data row1 col1" >1447.160034</td>
#       <td id="T_560eb_row1_col2" class="data row1 col2" >85.570000</td>
#       <td id="T_560eb_row1_col3" class="data row1 col3" >78.370003</td>
#       <td id="T_560eb_row1_col4" class="data row1 col4" >15.285000</td>
#       <td id="T_560eb_row1_col5" class="data row1 col5" >1.474491</td>
#     </tr>
#     <tr>
#       <td id="T_560eb_row2_col0" class="data row2 col0" >1/4/2008</td>
#       <td id="T_560eb_row2_col1" class="data row2 col1" >1411.630005</td>
#       <td id="T_560eb_row2_col2" class="data row2 col2" >85.129997</td>
#       <td id="T_560eb_row2_col3" class="data row2 col3" >77.309998</td>
#       <td id="T_560eb_row2_col4" class="data row2 col4" >15.167000</td>
#       <td id="T_560eb_row2_col5" class="data row2 col5" >1.475492</td>
#     </tr>
#     <tr>
#       <td id="T_560eb_row3_col0" class="data row3 col0" >1/7/2008</td>
#       <td id="T_560eb_row3_col1" class="data row3 col1" >1416.180054</td>
#       <td id="T_560eb_row3_col2" class="data row3 col2" >84.769997</td>
#       <td id="T_560eb_row3_col3" class="data row3 col3" >75.500000</td>
#       <td id="T_560eb_row3_col4" class="data row3 col4" >15.053000</td>
#       <td id="T_560eb_row3_col5" class="data row3 col5" >1.468299</td>
#     </tr>
#     <tr>
#       <td id="T_560eb_row4_col0" class="data row4 col0" >1/8/2008</td>
#       <td id="T_560eb_row4_col1" class="data row4 col1" >1390.189941</td>
#       <td id="T_560eb_row4_col2" class="data row4 col2" >86.779999</td>
#       <td id="T_560eb_row4_col3" class="data row4 col3" >76.059998</td>
#       <td id="T_560eb_row4_col4" class="data row4 col4" >15.590000</td>
#       <td id="T_560eb_row4_col5" class="data row4 col5" >1.557099</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Gradient background color for the numerical columns
gold_data.head(10).style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_188da_row0_col1, #T_188da_row0_col3, #T_188da_row1_col1, #T_188da_row4_col5, #T_188da_row8_col2, #T_188da_row8_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_188da_row0_col2 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_188da_row0_col4 {
#   background-color: #fee4d8;
#   color: #000000;
# }
# #T_188da_row0_col5 {
#   background-color: #ffece3;
#   color: #000000;
# }
# #T_188da_row1_col2 {
#   background-color: #fdd4c2;
#   color: #000000;
# }
# #T_188da_row1_col3 {
#   background-color: #6f020e;
#   color: #f1f1f1;
# }
# #T_188da_row1_col4 {
#   background-color: #fdcdb9;
#   color: #000000;
# }
# #T_188da_row1_col5 {
#   background-color: #fee7db;
#   color: #000000;
# }
# #T_188da_row2_col1 {
#   background-color: #fb7656;
#   color: #f1f1f1;
# }
# #T_188da_row2_col2 {
#   background-color: #fee8de;
#   color: #000000;
# }
# #T_188da_row2_col3 {
#   background-color: #bd151a;
#   color: #f1f1f1;
# }
# #T_188da_row2_col4 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_188da_row2_col5 {
#   background-color: #fee5d8;
#   color: #000000;
# }
# #T_188da_row3_col1, #T_188da_row8_col1 {
#   background-color: #f85d42;
#   color: #f1f1f1;
# }
# #T_188da_row3_col2, #T_188da_row3_col4, #T_188da_row5_col5, #T_188da_row9_col1, #T_188da_row9_col3 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_188da_row3_col3 {
#   background-color: #fb7151;
#   color: #f1f1f1;
# }
# #T_188da_row3_col5 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_188da_row4_col1, #T_188da_row7_col5 {
#   background-color: #fedccd;
#   color: #000000;
# }
# #T_188da_row4_col2 {
#   background-color: #fc8464;
#   color: #f1f1f1;
# }
# #T_188da_row4_col3 {
#   background-color: #f44d38;
#   color: #f1f1f1;
# }
# #T_188da_row4_col4 {
#   background-color: #fb7d5d;
#   color: #f1f1f1;
# }
# #T_188da_row5_col1 {
#   background-color: #fc8262;
#   color: #f1f1f1;
# }
# #T_188da_row5_col2 {
#   background-color: #fc9373;
#   color: #000000;
# }
# #T_188da_row5_col3 {
#   background-color: #fc7f5f;
#   color: #f1f1f1;
# }
# #T_188da_row5_col4 {
#   background-color: #fc9070;
#   color: #000000;
# }
# #T_188da_row6_col1 {
#   background-color: #f24633;
#   color: #f1f1f1;
# }
# #T_188da_row6_col2 {
#   background-color: #d11e1f;
#   color: #f1f1f1;
# }
# #T_188da_row6_col3 {
#   background-color: #fdc5ae;
#   color: #000000;
# }
# #T_188da_row6_col4 {
#   background-color: #b51318;
#   color: #f1f1f1;
# }
# #T_188da_row6_col5, #T_188da_row9_col5 {
#   background-color: #fed9c9;
#   color: #000000;
# }
# #T_188da_row7_col1 {
#   background-color: #fcaa8d;
#   color: #000000;
# }
# #T_188da_row7_col2 {
#   background-color: #bc141a;
#   color: #f1f1f1;
# }
# #T_188da_row7_col3 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_188da_row7_col4 {
#   background-color: #b11218;
#   color: #f1f1f1;
# }
# #T_188da_row8_col3 {
#   background-color: #fcb89e;
#   color: #000000;
# }
# #T_188da_row8_col5 {
#   background-color: #fcc3ab;
#   color: #000000;
# }
# #T_188da_row9_col2 {
#   background-color: #e12d26;
#   color: #f1f1f1;
# }
# #T_188da_row9_col4 {
#   background-color: #ec382b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_188da">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_188da_level0_col0" class="col_heading level0 col0" >Date</th>
#       <th id="T_188da_level0_col1" class="col_heading level0 col1" >SPX</th>
#       <th id="T_188da_level0_col2" class="col_heading level0 col2" >GLD</th>
#       <th id="T_188da_level0_col3" class="col_heading level0 col3" >USO</th>
#       <th id="T_188da_level0_col4" class="col_heading level0 col4" >SLV</th>
#       <th id="T_188da_level0_col5" class="col_heading level0 col5" >EUR/USD</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_188da_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_188da_row0_col0" class="data row0 col0" >1/2/2008</td>
#       <td id="T_188da_row0_col1" class="data row0 col1" >1447.160034</td>
#       <td id="T_188da_row0_col2" class="data row0 col2" >84.860001</td>
#       <td id="T_188da_row0_col3" class="data row0 col3" >78.470001</td>
#       <td id="T_188da_row0_col4" class="data row0 col4" >15.180000</td>
#       <td id="T_188da_row0_col5" class="data row0 col5" >1.471692</td>
#     </tr>
#     <tr>
#       <th id="T_188da_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_188da_row1_col0" class="data row1 col0" >1/3/2008</td>
#       <td id="T_188da_row1_col1" class="data row1 col1" >1447.160034</td>
#       <td id="T_188da_row1_col2" class="data row1 col2" >85.570000</td>
#       <td id="T_188da_row1_col3" class="data row1 col3" >78.370003</td>
#       <td id="T_188da_row1_col4" class="data row1 col4" >15.285000</td>
#       <td id="T_188da_row1_col5" class="data row1 col5" >1.474491</td>
#     </tr>
#     <tr>
#       <th id="T_188da_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_188da_row2_col0" class="data row2 col0" >1/4/2008</td>
#       <td id="T_188da_row2_col1" class="data row2 col1" >1411.630005</td>
#       <td id="T_188da_row2_col2" class="data row2 col2" >85.129997</td>
#       <td id="T_188da_row2_col3" class="data row2 col3" >77.309998</td>
#       <td id="T_188da_row2_col4" class="data row2 col4" >15.167000</td>
#       <td id="T_188da_row2_col5" class="data row2 col5" >1.475492</td>
#     </tr>
#     <tr>
#       <th id="T_188da_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_188da_row3_col0" class="data row3 col0" >1/7/2008</td>
#       <td id="T_188da_row3_col1" class="data row3 col1" >1416.180054</td>
#       <td id="T_188da_row3_col2" class="data row3 col2" >84.769997</td>
#       <td id="T_188da_row3_col3" class="data row3 col3" >75.500000</td>
#       <td id="T_188da_row3_col4" class="data row3 col4" >15.053000</td>
#       <td id="T_188da_row3_col5" class="data row3 col5" >1.468299</td>
#     </tr>
#     <tr>
#       <th id="T_188da_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_188da_row4_col0" class="data row4 col0" >1/8/2008</td>
#       <td id="T_188da_row4_col1" class="data row4 col1" >1390.189941</td>
#       <td id="T_188da_row4_col2" class="data row4 col2" >86.779999</td>
#       <td id="T_188da_row4_col3" class="data row4 col3" >76.059998</td>
#       <td id="T_188da_row4_col4" class="data row4 col4" >15.590000</td>
#       <td id="T_188da_row4_col5" class="data row4 col5" >1.557099</td>
#     </tr>
#     <tr>
#       <th id="T_188da_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_188da_row5_col0" class="data row5 col0" >1/9/2008</td>
#       <td id="T_188da_row5_col1" class="data row5 col1" >1409.130005</td>
#       <td id="T_188da_row5_col2" class="data row5 col2" >86.550003</td>
#       <td id="T_188da_row5_col3" class="data row5 col3" >75.250000</td>
#       <td id="T_188da_row5_col4" class="data row5 col4" >15.520000</td>
#       <td id="T_188da_row5_col5" class="data row5 col5" >1.466405</td>
#     </tr>
#     <tr>
#       <th id="T_188da_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_188da_row6_col0" class="data row6 col0" >1/10/2008</td>
#       <td id="T_188da_row6_col1" class="data row6 col1" >1420.329956</td>
#       <td id="T_188da_row6_col2" class="data row6 col2" >88.250000</td>
#       <td id="T_188da_row6_col3" class="data row6 col3" >74.019997</td>
#       <td id="T_188da_row6_col4" class="data row6 col4" >16.061001</td>
#       <td id="T_188da_row6_col5" class="data row6 col5" >1.480100</td>
#     </tr>
#     <tr>
#       <th id="T_188da_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_188da_row7_col0" class="data row7 col0" >1/11/2008</td>
#       <td id="T_188da_row7_col1" class="data row7 col1" >1401.020020</td>
#       <td id="T_188da_row7_col2" class="data row7 col2" >88.580002</td>
#       <td id="T_188da_row7_col3" class="data row7 col3" >73.089996</td>
#       <td id="T_188da_row7_col4" class="data row7 col4" >16.077000</td>
#       <td id="T_188da_row7_col5" class="data row7 col5" >1.479006</td>
#     </tr>
#     <tr>
#       <th id="T_188da_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_188da_row8_col0" class="data row8 col0" >1/14/2008</td>
#       <td id="T_188da_row8_col1" class="data row8 col1" >1416.250000</td>
#       <td id="T_188da_row8_col2" class="data

# %%
# last 5 rows of the dataframe
gold_data.tail()
# Out:
#            Date          SPX         GLD      USO      SLV   EUR/USD
# 2285   5/8/2018  2671.919922  124.589996  14.0600  15.5100  1.186789
# 2286   5/9/2018  2697.790039  124.330002  14.3700  15.5300  1.184722
# 2287  5/10/2018  2723.070068  125.180000  14.4100  15.7400  1.191753
# 2288  5/14/2018  2730.129883  124.489998  14.3800  15.5600  1.193118
# 2289  5/16/2018  2725.780029  122.543800  14.4058  15.4542  1.182033

# %%
# last 10 rows of the dataframe (Gradient background color)
gold_data.tail(10).style.background_gradient(cmap = 'Blues')
# Out:
# <style type="text/css">
# #T_8c2a6_row0_col1, #T_8c2a6_row5_col5 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_8c2a6_row0_col2, #T_8c2a6_row5_col2 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_8c2a6_row0_col3 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_8c2a6_row0_col4 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_8c2a6_row0_col5, #T_8c2a6_row7_col2, #T_8c2a6_row7_col3, #T_8c2a6_row7_col4, #T_8c2a6_row8_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_8c2a6_row1_col1 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_8c2a6_row1_col2 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_8c2a6_row1_col3, #T_8c2a6_row1_col4, #T_8c2a6_row3_col1, #T_8c2a6_row9_col2, #T_8c2a6_row9_col5 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_8c2a6_row1_col5, #T_8c2a6_row3_col2 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_8c2a6_row2_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_8c2a6_row2_col2, #T_8c2a6_row5_col1 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_8c2a6_row2_col3 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_8c2a6_row2_col4 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_8c2a6_row2_col5 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_8c2a6_row3_col3 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_8c2a6_row3_col4 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_8c2a6_row3_col5 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_8c2a6_row4_col1, #T_8c2a6_row9_col4 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_8c2a6_row4_col2 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_8c2a6_row4_col3 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_8c2a6_row4_col4 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_8c2a6_row4_col5 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_8c2a6_row5_col3 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_8c2a6_row5_col4 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_8c2a6_row6_col1, #T_8c2a6_row6_col2 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_8c2a6_row6_col3 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_8c2a6_row6_col4 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_8c2a6_row6_col5 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_8c2a6_row7_col1 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_8c2a6_row7_col5 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_8c2a6_row8_col2 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_8c2a6_row8_col3 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_8c2a6_row8_col4 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_8c2a6_row8_col5 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_8c2a6_row9_col1 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_8c2a6_row9_col3 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8c2a6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8c2a6_level0_col0" class="col_heading level0 col0" >Date</th>
#       <th id="T_8c2a6_level0_col1" class="col_heading level0 col1" >SPX</th>
#       <th id="T_8c2a6_level0_col2" class="col_heading level0 col2" >GLD</th>
#       <th id="T_8c2a6_level0_col3" class="col_heading level0 col3" >USO</th>
#       <th id="T_8c2a6_level0_col4" class="col_heading level0 col4" >SLV</th>
#       <th id="T_8c2a6_level0_col5" class="col_heading level0 col5" >EUR/USD</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8c2a6_level0_row0" class="row_heading level0 row0" >2280</th>
#       <td id="T_8c2a6_row0_col0" class="data row0 col0" >4/30/2018</td>
#       <td id="T_8c2a6_row0_col1" class="data row0 col1" >2648.050049</td>
#       <td id="T_8c2a6_row0_col2" class="data row0 col2" >124.589996</td>
#       <td id="T_8c2a6_row0_col3" class="data row0 col3" >13.800000</td>
#       <td id="T_8c2a6_row0_col4" class="data row0 col4" >15.380000</td>
#       <td id="T_8c2a6_row0_col5" class="data row0 col5" >1.208123</td>
#     </tr>
#     <tr>
#       <th id="T_8c2a6_level0_row1" class="row_heading level0 row1" >2281</th>
#       <td id="T_8c2a6_row1_col0" class="data row1 col0" >5/1/2018</td>
#       <td id="T_8c2a6_row1_col1" class="data row1 col1" >2654.800049</td>
#       <td id="T_8c2a6_row1_col2" class="data row1 col2" >123.709999</td>
#       <td id="T_8c2a6_row1_col3" class="data row1 col3" >13.610000</td>
#       <td id="T_8c2a6_row1_col4" class="data row1 col4" >15.240000</td>
#       <td id="T_8c2a6_row1_col5" class="data row1 col5" >1.199156</td>
#     </tr>
#     <tr>
#       <th id="T_8c2a6_level0_row2" class="row_heading level0 row2" >2282</th>
#       <td id="T_8c2a6_row2_col0" class="data row2 col0" >5/2/2018</td>
#       <td id="T_8c2a6_row2_col1" class="data row2 col1" >2635.669922</td>
#       <td id="T_8c2a6_row2_col2" class="data row2 col2" >123.650002</td>
#       <td id="T_8c2a6_row2_col3" class="data row2 col3" >13.670000</td>
#       <td id="T_8c2a6_row2_col4" class="data row2 col4" >15.420000</td>
#       <td id="T_8c2a6_row2_col5" class="data row2 col5" >1.195100</td>
#     </tr>
#     <tr>
#       <th id="T_8c2a6_level0_row3" class="row_heading level0 row3" >2283</th>
#       <td id="T_8c2a6_row3_col0" class="data row3 col0" >5/3/2018</td>
#       <td id="T_8c2a6_row3_col1" class="data row3 col1" >2629.729980</td>
#       <td id="T_8c2a6_row3_col2" class="data row3 col2" >124.279999</td>
#       <td id="T_8c2a6_row3_col3" class="data row3 col3" >13.820000</td>
#       <td id="T_8c2a6_row3_col4" class="data row3 col4" >15.460000</td>
#       <td id="T_8c2a6_row3_col5" class="data row3 col5" >1.198926</td>
#     </tr>
#     <tr>
#       <th id="T_8c2a6_level0_row4" class="row_heading level0 row4" >2284</th>
#       <td id="T_8c2a6_row4_col0" class="data row4 col0" >5/7/2018</td>
#       <td id="T_8c2a6_row4_col1" class="data row4 col1" >2672.629883</td>
#       <td id="T_8c2a6_row4_col2" class="data row4 col2" >124.570000</td>
#       <td id="T_8c2a6_row4_col3" class="data row4 col3" >14.100000</td>
#       <td id="T_8c2a6_row4_col4" class="data row4 col4" >15.520000</td>
#       <td id="T_8c2a6_row4_col5" class="data row4 col5" >1.193374</td>
#     </tr>
#     <tr>
#       <th id="T_8c2a6_level0_row5" class="row_heading level0 row5" >2285</th>
#       <td id="T_8c2a6_row5_col0" class="data row5 col0" >5/8/2018</td>
#       <td id="T_8c2a6_row5_col1" class="data row5 col1" >2671.919922</td>
#       <td id="T_8c2a6_row5_col2" class="data row5 col2" >124.589996</td>
#       <td id="T_8c2a6_row5_col3" class="data row5 col3" >14.060000</td>
#       <td id="T_8c2a6_row5_col4" class="data row5 col4" >15.510000</td>
#       <td id="T_8c2a6_row5_col5" class="data row5 col5" >1.186789</td>
#     </tr>
#     <tr>
#       <th id="T_8c2a6_level0_row6" class="row_heading level0 row6" >2286</th>
#       <td id="T_8c2a6_row6_col0" class="data row6 col0" >5/9/2018</td>
#       <td id="T_8c2a6_row6_col1" class="data row6 col1" >2697.790039</td>
#       <td id="T_8c2a6_row6_col2" class="data row6 col2" >124.330002</td>
#       <td id="T_8c2a6_row6_col3" class="data row6 col3" >14.370000</td>
#       <td id="T_8c2a6_row6_col4" class="data row6 col4" >15.530000</td>
#       <td id="T_8c2a6_row6_col5" class="data row6 col5" >1.184722</td>
#     </tr>
#     <tr>
#       <th id="T_8c2a6_level0_row7" class="row_heading level0 row7" >2287</th>
#       <td id="T_8c2a6_row7_col0" class="data row7 col0" >5/10/2018</td>
#       <td id="T_8c2a6_row7_col1" class="data row7 col1" >2723.070068</td>
#       <td id="T_8c2a6_row7_col2" class="data row7 col2" >125.180000</td>
#       <td id="T_8c2a6_row7_col3" class="data row7 col3" >14.410000</td>
#       <td id="T_8c2a6_row7_col4" class="data row7 col4" >15.740000</td>
#       <td id="T_8c2a6_row7_col5" class="data row7 col5" >1.191753</td>
#     </tr>
#     <tr>
#       <th id="T_8c2a6_level0_row8" class="row_heading level0 row8" >2288</th>
#       <td id="T_8c2a6_row8_col0" class="data row8 col0" >5/14/2018</td>
#       <td id="T_8c2a6_row8_col1" class="data row8 col1" >2730.129883</td>
#       <td id="T_8c2a6_row8_col2" class="data row8 col2" >124.489998</td>
#       <td id="T_8c2a6_row8_col3" clas

# %%
# number of rows(2290) and columns(6)
gold_data.shape
# Out:
# (2290, 6)

# %%
# the label of each column in the DataFrame
gold_data.columns
# Out:
# Index(['Date', 'SPX', 'GLD', 'USO', 'SLV', 'EUR/USD'], dtype='object')

# %%
# getting some informations about the dataset
gold_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2290 entries, 0 to 2289
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     2290 non-null   object
#  1   SPX      2290 non-null   float64
#  2   GLD      2290 non-null   float64
#  3   USO      2290 non-null   float64
#  4   SLV      2290 non-null   float64
#  5   EUR/USD  2290 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 107.5+ KB

# %%
plt.rcParams['figure.figsize'] = [12, 8]#resize the plot
#plt.figure(figsize = (12, 8))

gold_data.plot()
plt.show()

# %%
# Check for null values
gold_data.isnull().sum()
# Out:
# Date       0
# SPX        0
# GLD        0
# USO        0
# SLV        0
# EUR/USD    0
# dtype: int64

# %%
#Detect missing values
gold_data.isna().sum()
# Out:
# Date       0
# SPX        0
# GLD        0
# USO        0
# SLV        0
# EUR/USD    0
# dtype: int64

# %%
# statistical Measures of the dataset 
gold_data.describe()
# Out:
#                SPX          GLD          USO          SLV      EUR/USD
# count  2290.000000  2290.000000  2290.000000  2290.000000  2290.000000
# mean   1654.315776   122.732875    31.842221    20.084997     1.283653
# std     519.111540    23.283346    19.523517     7.092566     0.131547
# min     676.530029    70.000000     7.960000     8.850000     1.039047
# 25%    1239.874969   109.725000    14.380000    15.570000     1.171313
# 50%    1551.434998   120.580002    33.869999    17.268500     1.303297
# 75%    2073.010070   132.840004    37.827501    22.882500     1.369971
# max    2872.870117   184.589996   117.480003    47.259998     1.598798

# %%
# Transpose index and columns.(Gradient background color)
gold_data.describe().T.style.background_gradient(cmap = 'Blues')
# Out:
# <style type="text/css">
# #T_479fb_row0_col0, #T_479fb_row1_col0, #T_479fb_row2_col0, #T_479fb_row3_col0, #T_479fb_row4_col0, #T_479fb_row4_col1, #T_479fb_row4_col2, #T_479fb_row4_col3, #T_479fb_row4_col4, #T_479fb_row4_col5, #T_479fb_row4_col6, #T_479fb_row4_col7 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_479fb_row0_col1, #T_479fb_row0_col2, #T_479fb_row0_col3, #T_479fb_row0_col4, #T_479fb_row0_col5, #T_479fb_row0_col6, #T_479fb_row0_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_479fb_row1_col1 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_479fb_row1_col2 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_479fb_row1_col3 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_479fb_row1_col4 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_479fb_row1_col5 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_479fb_row1_col6, #T_479fb_row1_col7 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_479fb_row2_col1, #T_479fb_row2_col6, #T_479fb_row3_col7 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_479fb_row2_col2 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_479fb_row2_col3, #T_479fb_row2_col4, #T_479fb_row3_col1, #T_479fb_row3_col3, #T_479fb_row3_col4, #T_479fb_row3_col5, #T_479fb_row3_col6 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_479fb_row2_col5 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_479fb_row2_col7 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_479fb_row3_col2 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# </style>
# <table id="T_479fb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_479fb_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_479fb_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_479fb_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_479fb_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_479fb_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_479fb_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_479fb_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_479fb_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_479fb_level0_row0" class="row_heading level0 row0" >SPX</th>
#       <td id="T_479fb_row0_col0" class="data row0 col0" >2290.000000</td>
#       <td id="T_479fb_row0_col1" class="data row0 col1" >1654.315776</td>
#       <td id="T_479fb_row0_col2" class="data row0 col2" >519.111540</td>
#       <td id="T_479fb_row0_col3" class="data row0 col3" >676.530029</td>
#       <td id="T_479fb_row0_col4" class="data row0 col4" >1239.874969</td>
#       <td id="T_479fb_row0_col5" class="data row0 col5" >1551.434998</td>
#       <td id="T_479fb_row0_col6" class="data row0 col6" >2073.010070</td>
#       <td id="T_479fb_row0_col7" class="data row0 col7" >2872.870117</td>
#     </tr>
#     <tr>
#       <th id="T_479fb_level0_row1" class="row_heading level0 row1" >GLD</th>
#       <td id="T_479fb_row1_col0" class="data row1 col0" >2290.000000</td>
#       <td id="T_479fb_row1_col1" class="data row1 col1" >122.732875</td>
#       <td id="T_479fb_row1_col2" class="data row1 col2" >23.283346</td>
#       <td id="T_479fb_row1_col3" class="data row1 col3" >70.000000</td>
#       <td id="T_479fb_row1_col4" class="data row1 col4" >109.725000</td>
#       <td id="T_479fb_row1_col5" class="data row1 col5" >120.580002</td>
#       <td id="T_479fb_row1_col6" class="data row1 col6" >132.840004</td>
#       <td id="T_479fb_row1_col7" class="data row1 col7" >184.589996</td>
#     </tr>
#     <tr>
#       <th id="T_479fb_level0_row2" class="row_heading level0 row2" >USO</th>
#       <td id="T_479fb_row2_col0" class="data row2 col0" >2290.000000</td>
#       <td id="T_479fb_row2_col1" class="data row2 col1" >31.842221</td>
#       <td id="T_479fb_row2_col2" class="data row2 col2" >19.523517</td>
#       <td id="T_479fb_row2_col3" class="data row2 col3" >7.960000</td>
#       <td id="T_479fb_row2_col4" class="data row2 col4" >14.380000</td>
#       <td id="T_479fb_row2_col5" class="data row2 col5" >33.869999</td>
#       <td id="T_479fb_row2_col6" class="data row2 col6" >37.827501</td>
#       <td id="T_479fb_row2_col7" class="data row2 col7" >117.480003</td>
#     </tr>
#     <tr>
#       <th id="T_479fb_level0_row3" class="row_heading level0 row3" >SLV</th>
#       <td id="T_479fb_row3_col0" class="data row3 col0" >2290.000000</td>
#       <td id="T_479fb_row3_col1" class="data row3 col1" >20.084997</td>
#       <td id="T_479fb_row3_col2" class="data row3 col2" >7.092566</td>
#       <td id="T_479fb_row3_col3" class="data row3 col3" >8.850000</td>
#       <td id="T_479fb_row3_col4" class="data row3 col4" >15.570000</td>
#       <td id="T_479fb_row3_col5" class="data row3 col5" >17.268500</td>
#       <td id="T_479fb_row3_col6" class="data row3 col6" >22.882500</td>
#       <td id="T_479fb_row3_col7" class="data row3 col7" >47.259998</td>
#     </tr>
#     <tr>
#       <th id="T_479fb_level0_row4" class="row_heading level0 row4" >EUR/USD</th>
#       <td id="T_479fb_row4_col0" class="data row4 col0" >2290.000000</td>
#       <td id="T_479fb_row4_col1" class="data row4 col1" >1.283653</td>
#       <td id="T_479fb_row4_col2" class="data row4 col2" >0.131547</td>
#       <td id="T_479fb_row4_col3" class="data row4 col3" >1.039047</td>
#       <td id="T_479fb_row4_col4" class="data row4 col4" >1.171313</td>
#       <td id="T_479fb_row4_col5" class="data row4 col5" >1.303297</td>
#       <td id="T_479fb_row4_col6" class="data row4 col6" >1.369971</td>
#       <td id="T_479fb_row4_col7" class="data row4 col7" >1.598798</td>
#     </tr>
#   </tbody>
# </table>

# %%
#mean
# gold_data.mean()

# Convert all columns to numeric, coercing errors to NaNs
gold_data_numeric = gold_data.apply(pd.to_numeric, errors='coerce')

# Now calculate the mean
mean_values = gold_data_numeric.mean()

print(mean_values)
# Out:
# Date               NaN
# SPX        1654.315776
# GLD         122.732875
# USO          31.842221
# SLV          20.084997
# EUR/USD       1.283653
# dtype: float64

# %% [markdown]
# **we will not use the colum of date becouse our data does not depend on it.
# so we will deal with the other missing values.**

# %%
# drop the "date",after the cor
data = gold_data.drop(['Date'], axis=1)

# %%
#To check for duplicates
data.duplicated().sum()
# Out:
# 0

# %%
# Check for null values
data.isnull().sum()
# Out:
# SPX        0
# GLD        0
# USO        0
# SLV        0
# EUR/USD    0
# dtype: int64

# %% [markdown]
# **visualization**

# %%
#checking the distribution of the Gold Price.about outliers
sns.displot(data['USO'], color='green')
plt.title('USO Distribution')
plt.xlabel('USO Price')
plt.ylabel('Occurrences')
plt.show()

# %%
q = data["USO"].quantile(0.98)
data[data["USO"] > q]
data = data[(data["USO"] < q)]

# %%
#checking the distribution of the Gold Price.about outliers
sns.displot(data['USO'], color='green')
plt.title('USO Distribution')
plt.xlabel('USO Price')
plt.ylabel('Occurrences')
plt.show()

# %%
#checking the distribution of the Gold Price.about outliers
sns.displot(data['SPX'], color='blue')
plt.title('SPX Distribution')
plt.xlabel('SPX Price')
plt.ylabel('Occurrences')
plt.show()

# %%
#checking the distribution of the Gold Price.about outliers
sns.displot(data['GLD'], color='gold')
plt.title('Gold Distribution')
plt.xlabel('Gold Price')
plt.ylabel('Occurrences')
plt.show()

# %%
#checking the distribution of the Gold Price.about outliers
sns.displot(data['SLV'], color='silver')
plt.title('SLV Distribution')
plt.xlabel('SLV Price')
plt.ylabel('Occurrences')
plt.show()

# %%
#checking the distribution of the Gold Price.about outliers
sns.displot(data['EUR/USD'], color='cyan')
plt.title('EUR/USD exchange-rate Distribution')
plt.xlabel('EUR/USD exchange-rate')
plt.ylabel('Occurrences')
plt.show()

# %% [markdown]
# **Correlation**

# %%
# Compute pairwise correlation of columns 
# to identity the highly correlated features.
correlation = data.corr()

# %%
# Construct a heatmap to undestand the correlation
plt.figure(figsize= (8,8))
sns.heatmap(correlation, cbar=True, square=True, fmt='.2f', annot=True, annot_kws={'size':10}, cmap='Greens')
# Out:
# <Axes: >

# %%
# correlation values of Gold
print(correlation['GLD'])
# Out:
# SPX        0.032141
# GLD        1.000000
# USO       -0.091204
# SLV        0.874769
# EUR/USD    0.040271
# Name: GLD, dtype: float64

# %% [markdown]
# Splitting the data into a Training dataset & Testing dataset

# %%
# discard the gold and use the rest values as features
X = data.drop(['GLD'], axis=1)

# use the gold as the target
Y = data['GLD']

# %%
# The Features (input)
X
# The Features (input)(Gradient background color)
#X.style.background_gradient(cmap='Reds')
# Out:
#               SPX        USO      SLV   EUR/USD
# 0     1447.160034  78.470001  15.1800  1.471692
# 1     1447.160034  78.370003  15.2850  1.474491
# 2     1411.630005  77.309998  15.1670  1.475492
# 3     1416.180054  75.500000  15.0530  1.468299
# 4     1390.189941  76.059998  15.5900  1.557099
# ...           ...        ...      ...       ...
# 2285  2671.919922  14.060000  15.5100  1.186789
# 2286  2697.790039  14.370000  15.5300  1.184722
# 2287  2723.070068  14.410000  15.7400  1.191753
# 2288  2730.129883  14.380000  15.5600  1.193118
# 2289  2725.780029  14.405800  15.4542  1.182033
#
# [2244 rows x 4 columns]

# %%
# The target
Y
# The target(Gradient background color)
#Y.style.background_gradient(cmap='Reds')
# Out:
# 0        84.860001
# 1        85.570000
# 2        85.129997
# 3        84.769997
# 4        86.779999
#            ...
# 2285    124.589996
# 2286    124.330002
# 2287    125.180000
# 2288    124.489998
# 2289    122.543800
# Name: GLD, Length: 2244, dtype: float64

# %%
# Split arrays or matrices into random train and test subsets
#random_state #Testing the model with 20% of the dataset & training it with 80% of the model
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size= 0.2, random_state=0)

# %% [markdown]
# **Model Training: Random Forest Regressor**

# %%
regressor = RandomForestRegressor(n_estimators=100)

# %%
regressor
# Out:
# RandomForestRegressor()

# %%
# training the model
regressor.fit(X_train, Y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# Evalutation

# %%
# prediction on Test Data
test_data_prediction = regressor.predict(X_test)

# %%
print(test_data_prediction)
# Out:
# [ 86.14079953 104.57889791 127.20539765 132.23310136  96.05800014
#  125.54130172 165.43230152  91.79159889  76.46699862 120.00410044
#  146.67169734 127.22589954 124.92050024 116.31009849 133.47710227
#  102.72169902 107.12489975 133.85560111  86.9102992  139.00939975
#  112.38770013 124.69710076 117.25740034 114.14670097 116.99309987
#  120.18420154 159.39039905 119.11899997 156.722501   146.06250203
#  117.1063996  118.47030095  87.8431     160.54359834 147.78059964
#  117.96330073 109.91400019 111.35420025 160.27359618 111.64879907
#  140.50239918 115.28280047 123.20399952  72.26410189 126.17780021
#  168.31999868 108.61300021 107.48560097 125.29909956 154.33460123
#   93.96089986 160.25519605  90.80139869 112.6260019  109.4106975
#   84.19809968 156.69810001 156.16710266 127.75119981 172.16749895
#  165.60510225 123.89569889 107.85270111  79.3986998  118.96769897
#  128.90439914  93.41409902 154.43740164 125.86400118 138.11700363
#  125.5947013  101.25129871 124.16810112 114.56470051 171.37700225
#  120.77959996 120.49899976 116.49470097 117.79099944 136.72919944
#   77.74359928 117.05499995 122.26292725 159.75040039 122.7940007
#  144.82099784 119.05029979 113.4005016  125.78529956  91.4808005
#  162.90770198 112.39989998 120.98160068  84.16009832 108.58349846
#  120.76520072 146.25580284 128.42640161 128.23409931  87.42680046
#  105.5237995  132.7461028  120.24510154 132.2734997  118.70330018
#  117.27039965 158.99610131 122.70799987 155.38820154  92.64309891
#  123.53880046 156.11030365 117.50120139 119.42909908 108.54999937
#  148.15000235 163.18920094  92.24970111 121.48030176  94.63740068
#   90.80970062 125.32100031 107.0858991  117.81939991 147.21510051
#  153.21840189 116.0691991  155.52180129  88.41309898 170.66210185
#  124.4179006  122.4260011  113.7189004  121.20530037 126.67679794
#  113.1087012  140.01509981 154.6326999  120.94969991 125.91670006
#  117.30340069 176.6900974   95.61450109 120.06629929 123.51370126
#  163.86529869 120.51489904 110.61119861  97.34179866 118.98719949
#  101.65329976 102.18759922  91.92769873 126.69290042 125.29450017
#  115.79350035 118.60390072 167.7191991  137.15090514 153.52380167
#  126.04570022 112.55409987 101.67130021 114.75829879  92.06020018
#  132.38180197 166.66869855 124.47449871 125.68899969 119.30730059
#  121.00321389 119.16920011 108.06690095  90.67059963 118.92049922
#  117.67910052 123.57989895 121.89020037 114.37870005 136.99540056
#   90.90670101 107.97789937 116.59309998 141.07820097 120.68070071
#  114.78510036 119.06690048  97.85889924 125.96269993 116.7258013
#  128.10489904 165.45430036 115.02829893  73.4035016  153.49140127
#  140.85170092 127.56979697 135.36450121 139.1226022  118.86769985
#  159.31209951 163.46889805 156.92840534 127.59530001 118.1626003
#  125.11300017 168.20679953 127.88349996 122.2050004  139.73450107
#  160.6142021   93.2787989  117.65840022 155.73090043 113.58230017
#  110.15919853 156.17209908 117.94579929 118.97720108 113.88910045
#  118.14779872 123.46909901  82.43049881 116.70620057 152.35809945
#  155.97270033 123.65620038 114.82189973  89.57229988  87.36819882
#   91.54089834 103.79699882 109.75899948 111.19569924 116.57930075
#  142.47690054 117.46310083 114.40760134  96.14660038 116.23140091
#   88.83269959 126.68510175 114.24429963 106.57439864  88.2414991
#   99.90450082  83.46729943 103.92829849 131.71890163 121.68020037
#  160.83940106 102.9764986   89.73139968 127.92409954 148.69169942
#  107.32390018 124.29313794 120.61240065 115.20369925  75.79350003
#  125.41300035 109.30749899 120.71950006 111.87010011  93.6323992
#  125.19330067 120.96970213 110.1843979  109.2480991  159.76769957
#  112.40590111 158.63499995 121.32249986  95.34850094  89.84830118
#  139.15230087 114.93319953 119.66500061 127.70850015 127.01479927
#  104.27679834 126.88449949 115.77789991 114.85020013 107.23550045
#   91.39780105 121.60970038 125.91139911 118.72419997 121.99770071
#   80.65969943 135.2605984  125.99650033 166.98900115 128.08479734
#  120.51119935 115.59069897 148.63120064 105.13539812 124.4579013
#  119.82429932  87.48860041 132.23489909 132.24639999 122.57840035
#   92.62059934 134.28670011 117.43480002 120.76380206 126.23879952
#  160.69440084 108.48919951 136.55130084  84.19690035  93.23979866
#   90.73969837 115.2288004  108.69000035 132.39689944 117.95979859
#  122.0271007  128.49480217 126.03940131 133.69980342 120.23490059
#  159.95850023 115.75600007 107.60109979 136.84739637 127.59629943
#  173.8366981  111.65210028 165.0465967  114.88400007 111.50029975
#  144.21290203 111.33749895 156.08520211 128.1174001  114.30419854
#  112.15999956 155.27880065 127.06199743  88.96729976  92.77809951
#  113.69150036 134.07650082 118.86990177  90.13569964 163.63659812
#  116.95580173 120.52250123 113.84860008 102.53969942 125.13859896
#  125.24310035 137.95590031 127.1983009   87.74609877 120.08179982
#  166.4101965  115.1038006  134.22530011 110.83049951 122.90840114
#  107.48150099 120.48039873  99.82710072 116.30340022 127.4846986
#  155.96820015 159.80790154  92.66309915 122.1624003  109.62990097
#   96.4429995  119.66120158 126.24820078 126.09529953 120.77000037
#   88.09580119  93.38129802 113.06470082 115.92269823 155.61740182
#  106.53100056 113.25610127 113.72919891 120.64500065 101.10719843
#  131.53669878 132.4587009  128.21690011 156.10990121 149.72819805
#  119.02759969  90.10510116 102.69079887 117.82739902 115.2532999
#  132.00280135 166.78340075 128.67009761 154.85690027 103.4420996
#  116.52009906 144.16060014 117.66469874 118.16520025 108.67499932
#  118.65799913  92.50679924 141.36760276 111.74130149 114.39220035
#  129.45799954  94.01359957 124.84360144 120.72729949 123.84190003
#  119.96440074 166.32970273 154.18700026 155.24160212 118.94140095
#  114.22240134 127.6586996  160.35600202 165.8453011  126.85229932
#   76.88519891 120.76210037 123.67219896 118.11710135 115.09600042
#  130.02540127  88.04509959  98.69429899 117.22109996 127.50610032
#   86.53239863 115.69550039 111.90479969 157.96380121  94.13689962
#  116.68050122 116.89430017  87.94570074 132.2593033 ]

# %%
# R Squared error
error_score = metrics.r2_score(Y_test, test_data_prediction) # coefficient of determination, regression score function.
print('R squared error : ', error_score)
# Out:
# R squared error :  0.9871702883877383

# %% [markdown]
# **Compare the Actual Values and Predicted Values in a Plot**

# %%
Y_test = np.array(Y_test)
#Y_test = list(Y_test) #Converting the actual values to a list,so that it can be in the same format as the test_data_prediction

# %%
plt.rcParams['figure.figsize'] = [10, 8]#resize the plot
plt.plot(Y_test, color='blue', label='Actual Value')
plt.title('Actual Price vs Predicted Price')
plt.xlabel('Number of values')
plt.ylabel('Golden Price')
plt.legend()
plt.show()

# %%
plt.plot(test_data_prediction, color='red', label='Predicted value')
plt.title('Actual Price vs Predicted Price')
plt.xlabel('Number of values')
plt.ylabel('Golden Price')
plt.legend()
plt.show()

# %%
plt.plot(Y_test, color='blue', label='Actual Value')
plt.plot(test_data_prediction, color='red', label='Predicted value')
plt.title('Actual Price vs Predicted Price')
plt.xlabel('Number of values')
plt.ylabel('Golden Price')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (12,8))
plt.hist(Y_test, color='purple', label = 'Actual Value')
plt.hist(test_data_prediction, color='green', label='Predicted Value')
plt.title('Actual Price of Gold vs Predicted Price of Gold')
plt.xlabel('Number of values')
plt.ylabel('GOLD Price', rotation=30)
plt.legend()
plt.show()

# %% [markdown]
# **Building a System to use the model**

# %%
def convertor(user_input):
    
    for i in range(len(user_input)):
        user_input[i] = float(user_input[i])

    print("values = ", tuple(user_input))
    return tuple(user_input)

# %%
'''
print("how many values will you calculate: (NOTE: Press q to break)")
count = int(input())

while (count != 0):
    
    count = count-1
    input_string = input()
    user_input = input_string.split()
    if(input_string.lower() == "q"): 
        print("END")
        break
    input_data = convertor(user_input) 
    # changing input_data to a numpy array
    input_data_as_numpy_array = np.asarray(input_data)

    # reshape the array
    input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)#search

    # implementing the trained model
    prediction = regressor.predict(input_data_reshaped)
    print(prediction)

    print('The cost of the gold is:', prediction[0])
'''
# Out:
# '\nprint("how many values will you calculate: (NOTE: Press q to break)")\ncount = int(input())\n\nwhile (count != 0):\n    \n    count = count-1\n    input_string = input()\n    user_input = input_string.split()\n    if(input_string.lower() == "q"): \n        print("END")\n        break\n    input_data = convertor(user_input) \n    # changing input_data to a numpy array\n    input_data_as_numpy_array = np.asarray(input_data)\n\n    # reshape the array\n    input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)#search\n\n    # implementing the trained model\n    prediction = regressor.predict(input_data_reshaped)\n    print(prediction)\n\n    print(\'The cost of the gold is:\', prediction[0])\n'

# %%
# 1310.5 70.550003 15.902 1.464794              # row_15  ~ 88.169998
# 1336.910034 69.800003 16.674999 1.483107      # row_21  ~ 92.059998
# 1556.219971 33.040001 28.02 1.298802          # row_1144 ~ 152.990005
